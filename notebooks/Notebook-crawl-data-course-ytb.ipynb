# %% [markdown]
# # Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Điền link output path

# %%
destination_path = input("Please enter the destination path in your Google Drive (e.g., /content/drive/My Drive/My Videos): ")
# Out:
# Please enter the destination path in your Google Drive (e.g., /content/drive/My Drive/My Videos): /content/drive/MyDrive/DATA REF/LEARNING PATH

# %% [markdown]
# # Video Crawler

# %%
pip install yt-dlp
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2026.3.17-py3-none-any.whl.metadata (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 3.0 MB/s eta 0:00:00
# Downloading yt_dlp-2026.3.17-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 40.9 MB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2026.3.17

# %%
import yt_dlp

def download_playlist(playlist_url, output_path="CS230-video"):
    ydl_opts = {
        'outtmpl': f'{output_path}/%(playlist_title)s/%(title)s.%(ext)s',
        'format': 'bestvideo+bestaudio/best',
        'merge_output_format': 'mp4',
        'noplaylist': False,  # đảm bảo download cả playlist
    }

    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([playlist_url])
        print("Download hoàn tất!")
    except Exception as e:
        print("Lỗi:", e)


if __name__ == "__main__":
    url = input("Nhập link playlist: ")
    download_playlist(url)
# Out:
# Nhập link playlist: https://www.youtube.com/playlist?list=PLoROMvodv4rNRRGdS0rBbXOUGA0wjdh1X
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLoROMvodv4rNRRGdS0rBbXOUGA0wjdh1X
# [youtube:tab] PLoROMvodv4rNRRGdS0rBbXOUGA0wjdh1X: Downloading webpage
# [youtube:tab] PLoROMvodv4rNRRGdS0rBbXOUGA0wjdh1X: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Stanford CS230: Deep Learning I Autumn 2025
# [youtube:tab] PLoROMvodv4rNRRGdS0rBbXOUGA0wjdh1X page 1: Downloading API JSON
# [youtube:tab] Playlist Stanford CS230: Deep Learning I Autumn 2025: Downloading 9 items of 9
# [download] Downloading item 1 of 9
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_NLHFoVNlbg
# [youtube] _NLHFoVNlbg: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] _NLHFoVNlbg: Downloading android vr player API JSON
# [info] _NLHFoVNlbg: Downloading 1 format(s): 399+251
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 1： Introduction to Deep Learning.f399.mp4
# [download] 100% of  138.31MiB in 00:00:02 at 48.10MiB/s
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 1： Introduction to Deep Learning.f251.webm
# [download] 100% of   44.97MiB in 00:00:00 at 45.81MiB/s
# [Merger] Merging formats into "downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 1： Introduction to Deep Learning.mp4"
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 1： Introduction to Deep Learning.f251.webm (pass -k to keep)
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 1： Introduction to Deep Learning.f399.mp4 (pass -k to keep)
# [download] Downloading item 2 of 9
# [youtube] Extracting URL: https://www.youtube.com/watch?v=DNCn1BpCAUY
# [youtube] DNCn1BpCAUY: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] DNCn1BpCAUY: Downloading android vr player API JSON
# [info] DNCn1BpCAUY: Downloading 1 format(s): 399+251
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 2： Supervised, Self-Supervised, & Weakly Supervised Learning.f399.mp4
# [download] 100% of  190.35MiB in 00:00:04 at 39.43MiB/s
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 2： Supervised, Self-Supervised, & Weakly Supervised Learning.f251.webm
# [download] 100% of   80.16MiB in 00:00:01 at 47.09MiB/s
# [Merger] Merging formats into "downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 2： Supervised, Self-Supervised, & Weakly Supervised Learning.mp4"
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 2： Supervised, Self-Supervised, & Weakly Supervised Learning.f251.webm (pass -k to keep)
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 2： Supervised, Self-Supervised, & Weakly Supervised Learning.f399.mp4 (pass -k to keep)
# [download] Downloading item 3 of 9
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MGqQuQEUXhk
# [youtube] MGqQuQEUXhk: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] MGqQuQEUXhk: Downloading android vr player API JSON
# [info] MGqQuQEUXhk: Downloading 1 format(s): 399+251
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 3： Full Cycle of a DL project.f399.mp4
# [download] 100% of  215.06MiB in 00:00:04 at 46.99MiB/s
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 3： Full Cycle of a DL project.f251.webm
# [download] 100% of   52.57MiB in 00:00:02 at 21.09MiB/s
# [Merger] Merging formats into "downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 3： Full Cycle of a DL project.mp4"
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 3： Full Cycle of a DL project.f251.webm (pass -k to keep)
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 3： Full Cycle of a DL project.f399.mp4 (pass -k to keep)
# [download] Downloading item 4 of 9
# [youtube] Extracting URL: https://www.youtube.com/watch?v=aWlRtOlacYM
# [youtube] aWlRtOlacYM: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] aWlRtOlacYM: Downloading android vr player API JSON
# [info] aWlRtOlacYM: Downloading 1 format(s): 399+251
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 4： Adversarial Robustness and Generative Models.f399.mp4
# [download] 100% of  205.45MiB in 00:00:03 at 54.92MiB/s
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 4： Adversarial Robustness and Generative Models.f251.webm
# [download] 100% of   91.81MiB in 00:00:01 at 50.75MiB/s
# [Merger] Merging formats into "downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 4： Adversarial Robustness and Generative Models.mp4"
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 4： Adversarial Robustness and Generative Models.f251.webm (pass -k to keep)
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 4： Adversarial Robustness and Generative Models.f399.mp4 (pass -k to keep)
# [download] Downloading item 5 of 9
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4E27qlfYw0A
# [youtube] 4E27qlfYw0A: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 4E27qlfYw0A: Downloading android vr player API JSON
# [info] 4E27qlfYw0A: Downloading 1 format(s): 399+251
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 5： Deep Reinforcement Learning.f399.mp4
# [download] 100% of  158.87MiB in 00:00:03 at 51.22MiB/s
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 5： Deep Reinforcement Learning.f251.webm
# [download] 100% of   88.12MiB in 00:00:05 at 17.48MiB/s
# [Merger] Merging formats into "downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 5： Deep Reinforcement Learning.mp4"
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 5： Deep Reinforcement Learning.f399.mp4 (pass -k to keep)
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 5： Deep Reinforcement Learning.f251.webm (pass -k to keep)
# [download] Downloading item 6 of 9
# [youtube] Extracting URL: https://www.youtube.com/watch?v=s6JVGzABKho
# [youtube] s6JVGzABKho: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] s6JVGzABKho: Downloading android vr player API JSON
# [info] s6JVGzABKho: Downloading 1 format(s): 399+251
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 6： AI Project Strategy.f399.mp4
# [download] 100% of  171.37MiB in 00:00:10 at 16.86MiB/s
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 6： AI Project Strategy.f251.webm
# [download] 100% of   59.51MiB in 00:00:02 at 28.91MiB/s
# [Merger] Merging formats into "downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 6： AI Project Strategy.mp4"
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 6： AI Project Strategy.f399.mp4 (pass -k to keep)
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 6： AI Project Strategy.f251.webm (pass -k to keep)
# [download] Downloading item 7 of 9
# [youtube] Extracting URL: https://www.youtube.com/watch?v=k1njvbBmfsw
# [youtube] k1njvbBmfsw: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] k1njvbBmfsw: Downloading android vr player API JSON
# [info] k1njvbBmfsw: Downloading 1 format(s): 399+251
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 8： Agents, Prompts, and RAG.f399.mp4
# [download] 100% of  264.52MiB in 00:00:07 at 35.50MiB/s
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 8： Agents, Prompts, and RAG.f251.webm
# [download] 100% of   95.00MiB in 00:00:05 at 18.46MiB/s
# [Merger] Merging formats into "downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 8： Agents, Prompts, and RAG.mp4"
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 8： Agents, Prompts, and RAG.f251.webm (pass -k to keep)
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 8： Agents, Prompts, and RAG.f399.mp4 (pass -k to keep)
# [download] Downloading item 8 of 9
# [youtube] Extracting URL: https://www.youtube.com/watch?v=AuZoDsNmG_s
# [youtube] AuZoDsNmG_s: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] AuZoDsNmG_s: Downloading android vr player API JSON
# [info] AuZoDsNmG_s: Downloading 1 format(s): 399+251
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 9： Career Advice in AI.f399.mp4
# [download] 100% of  209.82MiB in 00:00:04 at 51.92MiB/s
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 9： Career Advice in AI.f251.webm
# [download] 100% of   81.29MiB in 00:00:01 at 51.31MiB/s
# [Merger] Merging formats into "downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 9： Career Advice in AI.mp4"
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 9： Career Advice in AI.f251.webm (pass -k to keep)
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 9： Career Advice in AI.f399.mp4 (pass -k to keep)
# [download] Downloading item 9 of 9
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ozb1AR_F5MU
# [youtube] Ozb1AR_F5MU: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Ozb1AR_F5MU: Downloading android vr player API JSON
# [info] Ozb1AR_F5MU: Downloading 1 format(s): 399+251
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 10： What’s Going On Inside My Model？.f399.mp4
# [download] 100% of  187.11MiB in 00:00:03 at 50.68MiB/s
# [download] Destination: downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 10： What’s Going On Inside My Model？.f251.webm
# [download] 100% of   83.85MiB in 00:00:03 at 26.01MiB/s
# [Merger] Merging formats into "downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 10： What’s Going On Inside My Model？.mp4"
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 10： What’s Going On Inside My Model？.f251.webm (pass -k to keep)
# Deleting original file downloads/Stanford CS230： Deep Learning I Autumn 2025/Stanford CS230 ｜ Autumn 2025 ｜ Lecture 10： What’s Going On Inside My Model？.f399.mp4 (pass -k to keep)
# [download] Finished downloading playlist: Stanford CS230: Deep Learning I Autumn 2025
# Download hoàn tất!

# %% [markdown]
# ## Chuyển playlist vào drive

# %% [markdown]
# Your Google Drive has been mounted. Now, please specify the exact path within your Google Drive where you want to move the `downloads` folder. For example: `/content/drive/My Drive/my_videos`

# %%
import shutil
import os

source_path = '/content/downloads'

# Ensure the destination directory exists
os.makedirs(destination_path, exist_ok=True)

try:
    # Move the downloads folder to the specified destination path
    shutil.move(source_path, destination_path)
    print(f"Successfully moved '{source_path}' to '{destination_path}'")
except shutil.Error as e:
    print(f"Error moving directory: {e}")
    print("It's possible the folder already exists in the destination, or there are permission issues.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Successfully moved '/content/downloads' to '/content/drive/MyDrive/DATA REF/LEARNING PATH'

# %% [markdown]
# This code attempts to move the entire `downloads` folder (which is located at `/content/downloads` by default) into the `destination_path` you provided in your Google Drive.

# %% [markdown]
# # Transcript Crawler

# %%
# !pip install yt-dlp youtube-transcript-api -q

# %%
import os
import re
import yt_dlp
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound

# ============================================================
# UTILS
# ============================================================

def seconds_to_timestamp(seconds):
    seconds = int(seconds)
    h = seconds // 3600
    m = (seconds % 3600) // 60
    s = seconds % 60
    return f"{h:02d}:{m:02d}:{s:02d}"

def sanitize_filename(name):
    name = re.sub(r'[\\/*?:"<>|]', "", name)
    name = name.strip().replace(" ", "_")
    return name[:100]

def get_playlist_videos(playlist_url):
    """Dùng yt-dlp để lấy danh sách video_id + title từ playlist"""
    ydl_opts = {
        "quiet": True,
        "extract_flat": True,   # chỉ lấy metadata, không download video
        "skip_download": True,
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(playlist_url, download=False)

    videos = []
    for entry in info.get("entries", []):
        if entry:
            videos.append({
                "id": entry.get("id"),
                "title": entry.get("title", f"video_{entry.get('id')}"),
                "url": f"https://www.youtube.com/watch?v={entry.get('id')}"
            })
    return videos

def get_transcript(video_id, languages=["en", "en-US", "en-GB"]):
    ytt_api = YouTubeTranscriptApi()
    try:
        # Lấy danh sách transcript available
        transcript_list = ytt_api.list(video_id)

        # Ưu tiên 1: manual transcript tiếng Anh
        try:
            transcript = transcript_list.find_manually_created_transcript(["en", "en-US", "en-GB"])
            return transcript.fetch()
        except Exception:
            pass

        # Ưu tiên 2: auto-generated tiếng Anh
        try:
            transcript = transcript_list.find_generated_transcript(["en", "en-US", "en-GB"])
            return transcript.fetch()
        except Exception:
            pass

        # Ưu tiên 3: lấy bất kỳ cái nào có
        for transcript in transcript_list:
            return transcript.fetch()

    except Exception as e:
        print(f"         ⚠️  Chi tiết lỗi: {e}")
        return None

def format_transcript(fetched_transcript):
    lines = []
    for snippet in fetched_transcript:
        timestamp = seconds_to_timestamp(snippet.start)
        lines.append(timestamp)
        lines.append(snippet.text)
        lines.append("")
    return "\n".join(lines)

# ============================================================
# MAIN PIPELINE
# ============================================================

def download_playlist_transcripts(playlist_url, output_dir="transcripts", languages=["en", "en-US", "en-GB"]):
    os.makedirs(output_dir, exist_ok=True)

    print(f"📋 Đang tải playlist metadata...\n")
    videos = get_playlist_videos(playlist_url)
    total = len(videos)
    print(f"🎬 Tìm thấy {total} video\n{'=' * 60}")

    success, skipped, failed = [], [], []

    for idx, video in enumerate(videos, start=1):
        video_id = video["id"]
        title_raw = video["title"]
        title = sanitize_filename(title_raw)
        filename = f"{title}_transcript.txt"
        filepath = os.path.join(output_dir, filename)

        print(f"[{idx}/{total}] 🎥 {title_raw}")

        if os.path.exists(filepath):
            print(f"         ⏭️  Đã tồn tại, bỏ qua\n")
            skipped.append(title)
            continue

        fetched = get_transcript(video_id, languages)
        if fetched is None:
            print(f"         ❌ Không lấy được transcript\n")
            failed.append(title_raw)
            continue

        content = format_transcript(fetched)
        with open(filepath, "w", encoding="utf-8") as f:
            f.write(f"Title: {title_raw}\n")
            f.write(f"URL: {video['url']}\n")
            f.write(f"Video ID: {video_id}\n")
            f.write("=" * 60 + "\n\n")
            f.write(content)

        print(f"         ✅ Lưu: {filename}\n")
        success.append(title)

    # Summary
    print("=" * 60)
    print(f"✅ Thành công : {len(success)}/{total}")
    print(f"⏭️  Bỏ qua    : {len(skipped)}/{total}")
    print(f"❌ Thất bại   : {len(failed)}/{total}")
    if failed:
        print(f"\nVideo không lấy được transcript:")
        for f in failed:
            print(f"  - {f}")
    print(f"\n📁 Output tại: /content/{output_dir}/")

# ============================================================
# RUN
# ============================================================

PLAYLIST_URL = "https://www.youtube.com/playlist?list=PLoROMvodv4rNRRGdS0rBbXOUGA0wjdh1X" # 

download_playlist_transcripts(
    playlist_url=PLAYLIST_URL,
    output_dir="CS230-transcript",
    languages=["en", "en-US", "en-GB"]
)
# Out:
# 📋 Đang tải playlist metadata...
#
# 🎬 Tìm thấy 9 video
# ============================================================
# [1/9] 🎥 Stanford CS230 | Autumn 2025 | Lecture 1: Introduction to Deep Learning
#          ⚠️  Chi tiết lỗi:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=_NLHFoVNlbg! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#          ❌ Không lấy được transcript
#
# [2/9] 🎥 Stanford CS230 | Autumn 2025 | Lecture 2: Supervised, Self-Supervised, & Weakly Supervised Learning
#          ⚠️  Chi tiết lỗi:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DNCn1BpCAUY! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#          ❌ Không lấy được transcript
#
# [3/9] 🎥 Stanford CS230 | Autumn 2025 | Lecture 3: Full Cycle of a DL project
#          ⚠️  Chi tiết lỗi:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=MGqQuQEUXhk! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#          ❌ Không lấy được transcript
#
# [4/9] 🎥 Stanford CS230 | Autumn 2025 | Lecture 4: Adversarial Robustness and Generative Models
#          ⚠️  Chi tiết lỗi:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=aWlRtOlacYM! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#          ❌ Không lấy được transcript
#
# [5/9] 🎥 Stanford CS230 | Autumn 2025 | Lecture 5: Deep Reinforcement Learning
#          ⚠️  Chi tiết lỗi:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=4E27qlfYw0A! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#          ❌ Không lấy được transcript
#
# [6/9] 🎥 Stanford CS230 | Autumn 2025 | Lecture 6: AI Project Strategy
#          ⚠️  Chi tiết lỗi:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=s6JVGzABKho! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#          ❌ Không lấy được transcript
#
# [7/9] 🎥 Stanford CS230 | Autumn 2025 | Lecture 8: Agents, Prompts, and RAG
#          ⚠️  Chi tiết lỗi:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=k1njvbBmfsw! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#          ❌ Không lấy được transcript
#
# [8/9] 🎥 Stanford CS230 | Autumn 2025 | Lecture 9: Career Advice in AI
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5275/902717186.py in <cell line: 0>()
#     139 PLAYLIST_URL = "https://www.youtube.com/playlist?list=PLoROMvodv4rNRRGdS0rBbXOUGA0wjdh1X"
#     140
# --> 141 download_playlist_transcripts(
#     142     playlist_url=PLAYLIST_URL,
#     143     output_dir="CS230-transcript",
#
# /tmp/ipykernel_5275/902717186.py in download_playlist_transcripts(playlist_url, output_dir, languages)
#     105             continue
#     106
# --> 107         fetched = get_transcript(video_id, languages)
#     108         if fetched is None:
#     109             print(f"         ❌ Không lấy được transcript\n")
#
# /tmp/ipykernel_5275/902717186.py in get_transcript(video_id, languages)
#      49         try:
#      50             transcript = transcript_list.find_manually_created_transcript(["en", "en-US", "en-GB"])
# ---> 51             return transcript.fetch()
#      52         except Exception:
#      53             pass
#
# /usr/local/lib/python3.12/dist-packages/youtube_transcript_api/_transcripts.py in fetch(self, preserve_formatting)
#     135         if "&exp=xpe" in self._url:
#     136             raise PoTokenRequired(self.video_id)
# --> 137         response = self._http_client.get(self._url)
#     138         snippets = _TranscriptParser(preserve_formatting=preserve_formatting).parse(
#     139             _raise_http_errors(response, self.video_id).text,
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     600
#     601         kwargs.setdefault("allow_redirects", True)
# --> 602         return self.request("GET", url, **kwargs)
#     603
#     604     def options(self, url, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.12/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in getresponse(self)
#     563
#     564         # Get the response from http.client.HTTPConnection
# --> 565         httplib_response = super().getresponse()
#     566
#     567         try:
#
# /usr/lib/python3.12/http/client.py in getresponse(self)
#    1448         try:
#    1449             try:
# -> 1450                 response.begin()
#    1451             except ConnectionError:
#    1452                 self.close()
#
# /usr/lib/python3.12/http/client.py in begin(self)
#     334         # read until we get a non-100 response
#     335         while True:
# --> 336             version, status, reason = self._read_status()
#     337             if status != CONTINUE:
#     338                 break
#
# /usr/lib/python3.12/http/client.py in _read_status(self)
#     295
#     296     def _read_status(self):
# --> 297         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298         if len(line) > _MAXLINE:
#     299             raise LineTooLong("status line")
#
# /usr/lib/python3.12/socket.py in readinto(self, b)
#     718         while True:
#     719             try:
# --> 720                 return self._sock.recv_into(b)
#     721             except timeout:
#     722                 self._timeout_occurred = True
#
# /usr/lib/python3.12/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1249                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250                   self.__class__)
# -> 1251             return self.read(nbytes, buffer)
#    1252         else:
#    1253             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.12/ssl.py in read(self, len, buffer)
#    1101         try:
#    1102             if buffer is not None:
# -> 1103                 return self._sslobj.read(len, buffer)
#    1104             else:
#    1105                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Chuyển script vào drive

# %%
import shutil
import os

source_path = '/content/downloads' # path to script folder

# Ensure the destination directory exists
os.makedirs(destination_path, exist_ok=True) # destination đã khai báo ở trên

try:
    # Move the downloads folder to the specified destination path
    shutil.move(source_path, destination_path)
    print(f"Successfully moved '{source_path}' to '{destination_path}'")
except shutil.Error as e:
    print(f"Error moving directory: {e}")
    print("It's possible the folder already exists in the destination, or there are permission issues.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
